# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
os.chdir(r"D:\Data Visulization")

# %%
data=pd.read_csv("hrdata.csv")
data2=pd.read_csv("MMix.csv")
data3=pd.read_csv("iris.csv")

# %% [markdown]
# ### Uni-variate Plots
# - Histograms
# - Density Plots
# - Box plots
# - Line Chart
#
# ### Bi-Variate Vlots
# - Heat Map
# - Scatter Plot
# - Pie Plot

# %% [markdown]
# ### Histogram

# %%
data.head()
# Out:
#    EmployeeCount  EmployeeID              Department                JobRole  \
# 0              1           1                   Sales        Sales Executive
# 1              1           2  Research & Development     Research Scientist
# 2              1           4  Research & Development  Laboratory Technician
# 3              1           5  Research & Development     Research Scientist
# 4              1           7  Research & Development  Laboratory Technician
#
#   Attrition  Gender  Age MaritalStatus      Education EducationField  \
# 0       Yes  Female   41        Single        College  Life Sciences
# 1        No    Male   49       Married  Below College  Life Sciences
# 2       Yes    Male   37        Single        College          Other
# 3        No  Female   33       Married         Master  Life Sciences
# 4        No    Male   27       Married  Below College        Medical
#
#           ...         Hourlyrate Income  Salaryhike OverTime  Workex  \
# ...

# %%
data2.head()
# Out:
#    NewVolSales  Base Price  Radio     TV   InStore  Facebook  Twitter  \
# 0        19564   15.029276   245.0  145.4   15.452         0        0
# 1        19387   15.029276   314.0   66.0   16.388         0        0
# 2        23889   14.585093   324.0  155.1   62.692         0        0
# 3        20055   15.332887   298.0  114.5   16.573         0        0
# 4        20064   15.642632   279.0   96.5   41.504         0        0
#
#    WebCamp  Online Website Campaign    ...         tvst60      tvst70  \
# 0        0       0               NaN   ...      87.240000  101.780000
# 1        0       0               NaN   ...      74.496000   76.734000
# 2        0       0               NaN   ...     122.858400  131.590200
# 3        0       0               NaN   ...     117.843360  119.627060
# 4        0       0               NaN   ...     105.037344  103.438118
#
#        tvst80      tvst90  radiost30  radiost60  radiost70  radiost80  \
# ...

# %%
data3.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(data['Income'],color='green',alpha=.1)
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['Income'],color='green',alpha=1)
# Out:
# (array([365., 349., 290., 109., 110.,  56.,  52.,  18.,  54.,  67.]),
#  array([ 1009.,  2908.,  4807.,  6706.,  8605., 10504., 12403., 14302.,
#         16201., 18100., 19999.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(data['Income'],color='green',alpha=1,bins=20)
# Out:
# (array([ 33., 332., 154., 195., 171., 119.,  69.,  40.,  42.,  68.,  38.,
#          18.,  21.,  31.,   7.,  11.,  30.,  24.,  21.,  46.]),
#  array([ 1009. ,  1958.5,  2908. ,  3857.5,  4807. ,  5756.5,  6706. ,
#          7655.5,  8605. ,  9554.5, 10504. , 11453.5, 12403. , 13352.5,
#         14302. , 15251.5, 16201. , 17150.5, 18100. , 19049.5, 19999. ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(data['Income'],color='green',alpha=1,bins=20,orientation='horizontal')
# Out:
# (array([ 33., 332., 154., 195., 171., 119.,  69.,  40.,  42.,  68.,  38.,
#          18.,  21.,  31.,   7.,  11.,  30.,  24.,  21.,  46.]),
#  array([ 1009. ,  1958.5,  2908. ,  3857.5,  4807. ,  5756.5,  6706. ,
#          7655.5,  8605. ,  9554.5, 10504. , 11453.5, 12403. , 13352.5,
#         14302. , 15251.5, 16201. , 17150.5, 18100. , 19049.5, 19999. ]),
#  <a list of 20 Patch objects>)

# %%
plt.figure(figsize=(15,7))
plt.hist(data['Income'],color='green',alpha=1,bins=20)
plt.xlabel("Income")
plt.ylabel("Freqency (No of Employees)")
plt.title("Histogram For Income")
plt.show()

# %%
from matplotlib import style
style.use("classic")

# %%
plt.figure(figsize=(15,7))
plt.hist(data['Income'],color='green',alpha=1,bins=20)
plt.xlabel("Income")
plt.ylabel("Freqency (No of Employees)")
plt.title("Histogram For Income")
plt.show()
#plt.savefig("Histogram.png")
#plt.savefig("Histogram.pdf")

# %% [markdown]
# ### Density plot

# %%
data['Income'].plot(kind='density')

# %%
data['Income'].plot(kind='density',ls="--")
plt.xlabel("Income")
plt.ylabel("Freqency (No of Employees)")
plt.title("Histogram For Income")
# Out:
# Text(0.5, 1.0, 'Histogram For Income')

# %% [markdown]
# ### Histogram with Density Plot

# %%
print(style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
plt.figure(figsize=(15,7))
ax=data['Income'].plot(kind='hist',color='lightblue')
ax2=data['Income'].plot(kind='density',color='green',secondary_y=True,ls="--")
ax.set_ylabel("Frequency (No Of Employees)")
ax2.set_ylabel("Density")
ax.set_xlabel("Income")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plot

# %%
plt.boxplot(data['Income'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e1e1a8cda0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e1e1a54128>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e1e1a8cd68>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e1e1a54828>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e1e1a9e978>],
#  'means': []}

# %%
plt.boxplot(data['Income'],vert=False)
plt.figure(figsize=(15,7))

# %%
data3.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data3['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.boxplot(data=data3,orient='h',palette="Set3")
plt.figure(figsize=(15,7))

# %% [markdown]
# ### Line chart

# %%
plt.figure(figsize=(15,7))
plt.plot(data2['NewVolSales'])
plt.xlabel("week")
plt.ylabel("Sales In Thousands")
plt.title("Volume Sales")
# Out:
# Text(0.5, 1.0, 'Volume Sales')

# %% [markdown]
# ### Bi-Variant Plot
# #### Scatter Plot

# %%
plt.scatter(x=data['Age'],y=data['Income'],color='green',alpha=0.8)

# %% [markdown]
# ### Heat map

# %%
sns.heatmap(data3.corr(),annot=True)
